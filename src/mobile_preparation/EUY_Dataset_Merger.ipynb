# %%
from google.colab import files
files.upload()

# %%
# !unzip "Recipes Dataset.zip"
# Out:
# Archive:  Recipes Dataset.zip
#   inflating: Recipes Dataset/dataset-ayam.csv
#   inflating: Recipes Dataset/dataset-tempe.csv
#   inflating: Recipes Dataset/dataset-sapi.csv
#   inflating: Recipes Dataset/dataset-kambing.csv
#   inflating: Recipes Dataset/dataset-ikan.csv
#   inflating: Recipes Dataset/dataset-udang.csv
#   inflating: Recipes Dataset/dataset-telur.csv
#   inflating: Recipes Dataset/dataset-tahu.csv

# %%
import pandas as pd

dataset_directory = "Recipes Dataset"

dataset_ayam = pd.read_csv(f"{dataset_directory}/dataset-ayam.csv")
dataset_tempe = pd.read_csv(f"{dataset_directory}/dataset-tempe.csv")
dataset_sapi = pd.read_csv(f"{dataset_directory}/dataset-sapi.csv")
dataset_kambing = pd.read_csv(f"{dataset_directory}/dataset-kambing.csv")
dataset_ikan = pd.read_csv(f"{dataset_directory}/dataset-ikan.csv")
dataset_udang = pd.read_csv(f"{dataset_directory}/dataset-udang.csv")
dataset_telur = pd.read_csv(f"{dataset_directory}/dataset-telur.csv")
dataset_tahu = pd.read_csv(f"{dataset_directory}/dataset-tahu.csv")

list_recipes_dataset = [
    dataset_ayam,
    dataset_tempe,
    dataset_sapi,
    dataset_kambing,
    dataset_ikan,
    dataset_udang,
    dataset_telur,
    dataset_tahu
]

# %%
recipes_dataset = pd.concat(list_recipes_dataset, ignore_index=True)
del recipes_dataset[recipes_dataset.columns[0]]
recipes_dataset.head()
# Out:
#                       Title  \
# 0          Ayam Woku Manado
# 1  Ayam goreng tulang lunak
# 2          Ayam cabai kawin
# 3               Ayam Geprek
# 4               Minyak Ayam
#
#                                          Ingredients  \
# 0  1 Ekor Ayam Kampung (potong 12)--2 Buah Jeruk ...
# 1  1 kg ayam (dipotong sesuai selera jangan kecil...
# 2  1/4 kg ayam--3 buah cabai hijau besar--7 buah ...
# 3  250 gr daging ayam (saya pakai fillet)--Secuku...
# 4  400 gr kulit ayam & lemaknya--8 siung bawang p...
#
#                                                Steps  Loves  \
# 0  Cuci bersih ayam dan tiriskan. Lalu peras jeru...      1
# 1  Haluskan bumbu2nya (BaPut, ketumbar, kemiri, k...      1
# 2  Panaskan minyak di dalam wajan. Setelah minyak...      2
# 3  Goreng ayam seperti ayam krispi--Ulek semua ba...     10
# 4  Cuci bersih kulit ayam. Sisihkan--Ambil 50 ml ...      4
#
#                                           URL  \
# 0          /id/resep/4473027-ayam-woku-manado
# ...

# %%
recipes_dataset = recipes_dataset.rename(columns = {
    'Title': 'name',
    'Ingredients':'ingredients',
    'Steps': 'steps',
    'Loves': 'loves',
    'URL': 'url'
    })
recipes_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         395 non-null    object
#  1   ingredients  395 non-null    object
#  2   steps        395 non-null    object
#  3   loves        395 non-null    int64
#  4   url          395 non-null    object
#  5   description  254 non-null    object
#  6   image        391 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 21.7+ KB

# %%
recipes_dataset = recipes_dataset.sample(frac=1).reset_index(drop=True)
recipes_dataset.head()
# Out:
#                                     name  \
# 0  Udang Sambal Petai (Sangat Sederhana)
# 1       Sayur tempe mix tahu alaala kari
# 2                       Sambal ikan Lele
# 3            Orak arik telur daging sapi
# 4                       Tumis Tahu Bubuk
#
#                                          ingredients  \
# 0  1/4 kg Udang--Petai 1 keris--Minyak secukupnya...
# 1  1/4 tempe dari 1 papan--5 buah tahu--2 keris p...
# 2  1/2 kg ikan lele (cuci bersih potong jd bebera...
# 3  1/2 kg Daging sapi--Bawang putih 1 bungkul cin...
# 4  8 Tahu Kuning--5 Siung Bawang Merah--4 Siung B...
#
#                                                steps  loves  \
# 0  Cuci semua bahan dan bumbu.--Blender bumbu den...      7
# 1  Tempe potong kotak, goreng--Tahu potong serong...      5
# 2  Cuci bersih ikan lele (tips biar lele gak lici...      5
# 3  Tumis bawang putih sampai harum masukkan dagin...      0
# 4  Tumbuk kasar tahu kuning. Sisihkan.--Tumis baw...      2
#
# ...

# %%
recipes_dataset.to_csv("recipes-dataset.csv")
